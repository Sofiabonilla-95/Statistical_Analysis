# %%
# !pip install wordcloud
# Out:
# ...
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\sofia\appdata\local\programs\python\python39\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\sofia\\AppData\\Local\\Temp\\pip-install-visj6jom\\wordcloud_6923d2dea6234b31bd72cfee81db24b4\\setup.py'"'"'; __file__='"'"'C:\\Users\\sofia\\AppData\\Local\\Temp\\pip-install-visj6jom\\wordcloud_6923d2dea6234b31bd72cfee81db24b4\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\sofia\AppData\Local\Temp\pip-record-_jwbb_gv\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\users\sofia\appdata\local\programs\python\python39\Include\wordcloud'
# ...

# %%
import pandas as pd
from datetime import datetime
import re
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud
#Importing Dataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21608/1727399824.py in <module>
#       4 import matplotlib.pyplot as plt
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 6 from wordcloud import WordCloud
#       7 #Importing Dataset
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
movies=pd.read_csv('IMDb movies.csv')
# Out:
# C:\Users\sofia\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
movies.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
# ...

# %%
ratings=pd.read_csv('IMDb ratings_2.csv')

# %%
ratings.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000009                    5.9          154        5.9          6.0
# 1     tt0000574                    6.1          589        6.3          6.0
# 2     tt0001892                    5.8          188        6.0          6.0
# 3     tt0002101                    5.2          446        5.3          5.0
# 4     tt0002130                    7.0         2237        6.9          7.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6  ...  females_30age_avg_vote  \
# 0        12        4       10       43       28  ...                     5.7
# 1        57       18       58      137      139  ...                     6.6
# 2         6        6       17       44       52  ...                     6.2
# 3        15        8       16       62       98  ...                     5.5
# 4       210      225      436      641      344  ...                     7.3
#
# ...

# %%
movies.drop(columns=['date_published','usa_gross_income','writer','production_company',
                     'language','country','budget','worlwide_gross_income','reviews_from_users','reviews_from_critics','metascore'],inplace=True)

# %%
movies.dropna()
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85848     tt9905462                       Pengalila
# 85849     tt9906644                       Manoharam
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year                      genre  \
# 0                          Miss Jerry  1894                    Romance
# 1         The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 2                      Den sorte drøm  1911                      Drama
# ...

# %%
sub_df=movies["genre"].str.split(',', expand=True)

# %%
sub_df
# Out:
#                0         1         2
# 0        Romance      None      None
# 1      Biography     Crime     Drama
# 2          Drama      None      None
# 3          Drama   History      None
# 4      Adventure     Drama   Fantasy
# ...          ...       ...       ...
# 85850     Comedy      None      None
# 85851     Comedy     Drama      None
# 85852      Drama      None      None
# 85853      Drama    Family      None
# 85854      Drama      None      None
#
# [85855 rows x 3 columns]

# %%
sub_df.columns = ["genre1",'no','no1']

# %%
imdb=pd.concat([movies, sub_df], axis=1)

# %%
imdb
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year                      genre  \
# 0                          Miss Jerry  1894                    Romance
# 1         The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 2                      Den sorte drøm  1911                      Drama
# ...

# %%
imdb.drop(columns=['no','no1'],inplace=True)

# %%
imdb
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year                      genre  \
# 0                          Miss Jerry  1894                    Romance
# 1         The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 2                      Den sorte drøm  1911                      Drama
# ...

# %%
imdb.dropna()
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85848     tt9905462                       Pengalila
# 85849     tt9906644                       Manoharam
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year                      genre  \
# 0                          Miss Jerry  1894                    Romance
# 1         The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 2                      Den sorte drøm  1911                      Drama
# ...

# %%
imdb.groupby('genre1')['avg_vote'].agg({'mean'})
# Out:
#                  mean
# genre1
# Action       5.577409
# Adult        4.550000
# Adventure    5.869881
# Animation    6.386575
# Biography    6.638413
# Comedy       5.877100
# Crime        6.103743
# Documentary  7.300000
# Drama        6.268865
# Family       5.591693
# Fantasy      5.353586
# Film-Noir    6.603448
# History      5.945000
# Horror       4.607432
# Music        6.283117
# Musical      6.205247
# Mystery      5.767454
# Romance      5.954759
# Sci-Fi       4.554436
# Sport        5.475000
# Thriller     5.174182
# War          6.078505
# Western      5.805673

# %%
total_votes=imdb.groupby('genre1')['votes'].agg({'sum'})
total_votes
# Out:
#                    sum
# genre1
# Action       259593053
# Adult             1379
# Adventure     50744360
# Animation     47118890
# Biography     44417762
# Comedy       156351274
# Crime         64467790
# Documentary       1231
# Drama        142609516
# Family         1164022
# Fantasy        3468624
# Film-Noir       408478
# History          38781
# Horror        33013567
# Music            48701
# Musical         446256
# Mystery        6140845
# Romance         839673
# Sci-Fi         1210088
# Sport             5977
# Thriller       1177511
# War              62083
# Western        1733689

# %%
total=imdb['votes'].sum()
total
# Out:
# 815063550

# %%
total_votes/total*100
# Out:
#                    sum
# genre1
# Action       31.849425
# Adult         0.000169
# Adventure     6.225816
# Animation     5.781008
# Biography     5.449607
# Comedy       19.182710
# Crime         7.909542
# Documentary   0.000151
# Drama        17.496736
# Family        0.142814
# Fantasy       0.425565
# Film-Noir     0.050116
# History       0.004758
# Horror        4.050429
# Music         0.005975
# Musical       0.054751
# Mystery       0.753419
# Romance       0.103019
# Sci-Fi        0.148465
# Sport         0.000733
# Thriller      0.144469
# War           0.007617
# Western       0.212706

# %%
peliculas=imdb.groupby(['title','votes','avg_vote'])['votes'].agg({'sum'})
peliculas_1=peliculas.reset_index()

# %%
peliculas_1.sort_values(by=['votes'], inplace=True, ascending=False)

# %%
peliculas_1.head(20)
# Out:
#                                                    title    votes  avg_vote  \
# 44843                               Le ali della libertà  2278845       9.3
# 31138                                Il cavaliere oscuro  2241615       9.0
# 34087                                          Inception  2002816       8.8
# 22564                                         Fight Club  1807440       8.8
# 60221                                       Pulp Fiction  1780147       8.9
# 23260                                       Forrest Gump  1755490       8.8
# 49524                                             Matrix  1632315       8.7
# 30844  Il Signore degli Anelli - La compagnia dell'An...  1619920       8.8
# 30843        Il Signore degli Anelli - Il ritorno del re  1604280       8.9
# 32524                                         Il padrino  1572674       9.2
# 31139                   Il cavaliere oscuro - Il ritorno  1480582       8.4
# ...

# %%
peliculas_2=peliculas_1.sort_values(by=['avg_vote'], ascending=False)

# %%
peliculas_2.head(10)
# Out:
#                                    title  votes  avg_vote   sum
# 70127                    Suvarna Sundari    896       9.9   896
# 45757  Lejos de Casa pelicula Venezolana    133       9.8   133
# 35640                             Jeeudo    130       9.8   130
# 19970                                 Ek    527       9.8   527
# 54688                        Notuku Potu    926       9.8   926
# 81077                Vaarthakal Ithuvare    473       9.7   473
# 49899                          Meka Suri   1126       9.7  1126
# 28804                      Hopeful Notes    669       9.7   669
# 74781                The Moving on Phase    172       9.5   172
# 34901                               Isha    392       9.5   392

# %%
#IMPORTAMOS RECURSOS.
from wordcloud import WordCloud
import matplotlib.pyplot as plt

#OBTENEMOS TEXTO DE "wikipedia".
info = wikipedia.summary("Python")
print(info)

#GENERAR NUBE
wordCloud = WordCloud().generate(info)

#MOSTRAR NUBE.
plt.imshow(wordCloud,interpolation='bilinear')
plt.axis("off")
plt.show()

image = wordCloud.to_image()
image.save("wordcloud.png")
image.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21608/2133519139.py in <module>
#       1 #IMPORTAMOS RECURSOS.
# ----> 2 from wordcloud import WordCloud
#       3 import matplotlib.pyplot as plt
#       4
#       5 #OBTENEMOS TEXTO DE "wikipedia".
#
# ModuleNotFoundError: No module named 'wordcloud'
